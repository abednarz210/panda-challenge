# %%
#Begin Panda Challenge Pycity 
import pandas as pd

# %%
#files for import 
csv_path = "../resources/schools_complete.csv"

schools_df = pd.read_csv(csv_path)
schools_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
#Distict snapshot 
schools_df.describe()
# Out:
#        School ID         size        budget
# count  15.000000    15.000000  1.500000e+01
# mean    7.000000  2611.333333  1.643295e+06
# std     4.472136  1420.915282  9.347763e+05
# min     0.000000   427.000000  2.480870e+05
# 25%     3.500000  1698.000000  1.046265e+06
# 50%     7.000000  2283.000000  1.319574e+06
# 75%    10.500000  3474.000000  2.228999e+06
# max    14.000000  4976.000000  3.124928e+06

# %%
schools_df["size"].sum()
# Out:
# 39170

# %%
schools_df["school_name"].count()
# Out:
# 15

# %%
schools_df["budget"].sum()
# Out:
# 24649428

# %%
#files for import 
csv_path = "../resources/students_complete.csv"

students_df = pd.read_csv(csv_path)
students_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Merge two dataframes using an inner join
schools_merge_df = pd.merge(students_df, schools_df, how = "left", on="school_name")
schools_merge_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
schools_merge_df.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
#pass rate for math 
pass_math = schools_merge_df.loc[schools_merge_df["math_score"] >=70]
pass_math
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
#final pass rate 
pass_math = (29370/39169)*100
pass_math
# Out:
# 74.98276698409457

# %%
#pass rate reading
pass_reading = schools_merge_df.loc[schools_merge_df["reading_score"] >=70]
pass_reading
# Out:
#        Student ID     student_name gender grade         school_name  \
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 1                 94          61          0  District  2917  1910635
# ...

# %%
#final pass Rate 
pass_reading = (33610/39169)*100
pass_reading
# Out:
# 85.80765401210141

# %%
#calculate total math and reading
overall_pass = schools_merge_df.loc[(schools_merge_df["math_score"] >=70) & (schools_merge_df ["reading_score"] >=70)]
overall_pass
# Out:
#        Student ID     student_name gender grade         school_name  \
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# 9               9   Matthew Greene      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 4                 97          84          0  District  2917  1910635
# ...

# %%
overall_pass_percent = (25528/39169) * 100
overall_pass_percent
# Out:
# 65.17398963466007

# %%
# Initialise data to lists.
data = [{'Total Students': 39170, 'Total Schools': 15, 'Total Budget $': "24,649,428",
        'Average Math Score in %':78.98, 'Average Reading Score in %': 81.87, '% Passing Reading': 85.81, 
        '% Passing Math': 74.98,'Overall Passing %': 65.17}]

# Creates DataFrame.
df = pd.DataFrame(data)

# Print the data
df
# Out:
#    Total Students  Total Schools Total Budget $  Average Math Score in %  \
# 0           39170             15     24,649,428                    78.98
#
#    Average Reading Score in %  % Passing Reading  % Passing Math  \
# 0                       81.87              85.81           74.98
#
#    Overall Passing %
# 0              65.17

# %%
#data by school by group 
school_name = schools_merge_df.set_index("school_name").groupby(["school_name"])
school_name.head()
# Out:
#                     Student ID       student_name gender grade  reading_score  \
# school_name
# Huang High School            0       Paul Bradley      M   9th             66
# Huang High School            1       Victor Smith      M  12th             94
# Huang High School            2    Kevin Rodriguez      M  12th             90
# Huang High School            3  Dr. Richard Scott      M  12th             67
# Huang High School            4         Bonnie Ray      F   9th             97
# ...                        ...                ...    ...   ...            ...
# Thomas High School       37535         Norma Mata      F  10th             76
# Thomas High School       37536        Cody Miller      M  11th             84
# Thomas High School       37537        Erik Snyder      M   9th             80
# Thomas High School       37538     Tanya Martinez      F   9th             71
# Thomas High School       37539      Noah Erickson      M   9th             86
#
# ...

# %%
#data by school by types
school_type = schools_merge_df.set_index("school_name").groupby(["type"])
school_type.count()
# Out:
#           Student ID  student_name  gender  grade  reading_score  math_score  \
# type
# Charter        12194         12194   12194  12194          12194       12194
# District       26976         26976   26976  26976          26976       26976
#
#           School ID   size  budget
# type
# Charter       12194  12194   12194
# District      26976  26976   26976

# %%
#total students 
total_students = schools_merge_df['Student ID']
total_students.count()
# Out:
# 39170

# %%
average_math_score = school_name['math_score'].mean()
print(average_math_score)
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
average_math_score = school_name['reading_score'].mean()
print(average_math_score)
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
#total budget
total_budget = schools_merge_df.set_index("school_name")['budget']
print (total_budget)
# Out:
# school_name
# Huang High School     1910635
# Huang High School     1910635
# Huang High School     1910635
# Huang High School     1910635
# Huang High School     1910635
#                        ...
# Thomas High School    1043130
# Thomas High School    1043130
# Thomas High School    1043130
# Thomas High School    1043130
# Thomas High School    1043130
# Name: budget, Length: 39170, dtype: int64

# %%
#total per student budget
total_spending = (schools_merge_df.set_index('school_name')['budget']/schools_merge_df.set_index('school_name')["size"])
print(total_spending)
# Out:
# school_name
# Huang High School     655.0
# Huang High School     655.0
# Huang High School     655.0
# Huang High School     655.0
# Huang High School     655.0
#                       ...
# Thomas High School    638.0
# Thomas High School    638.0
# Thomas High School    638.0
# Thomas High School    638.0
# Thomas High School    638.0
# Length: 39170, dtype: float64

# %%
#total students by school
total_students = schools_merge_df.groupby("school_name")['Student ID']
total_students.count()
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: Student ID, dtype: int64

# %%
#pass rate math
pass_rate_math = schools_merge_df[schools_merge_df["math_score"] >=70].groupby ("school_name")["size"]
pass_rate_math.count()
# Out:
# school_name
# Bailey High School       3318
# Cabrera High School      1749
# Figueroa High School     1946
# Ford High School         1871
# Griffin High School      1371
# Hernandez High School    3094
# Holden High School        395
# Huang High School        1916
# Johnson High School      3145
# Pena High School          910
# Rodriguez High School    2654
# Shelton High School      1653
# Thomas High School       1525
# Wilson High School       2143
# Wright High School       1680
# Name: size, dtype: int64

# %%
#total students by school
total_students = schools_merge_df.groupby("school_name")['Student ID']
total_students.count()
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: Student ID, dtype: int64

# %%
#pass rate for reading
pass_reading = schools_merge_df[schools_merge_df["reading_score"] >=70].groupby("school_name")["size"].count
pass_reading()
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1591
# Wilson High School       2204
# Wright High School       1739
# Name: size, dtype: int64

# %%
schools_merge_df.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')
